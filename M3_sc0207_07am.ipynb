# %% [markdown]
# <a href="https://colab.research.google.com/github/amf60/vac_covid19_sc_Combinations-of-Concern/blob/main/M3_sc0207_07am.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <Font color = 'brown'>**Covid-19 vaccination records in the Brazilian state of Santa Catarina**
#
# <Font color = 'brown'>**COMBINATIONS OF CONCERN - CoC**
#
#
# *   Clinical Data Scientist: Aldir MEDEIROS FILHO
# *   FLORIANOPOLIS, [Santa Catarina(SC)](https://en.wikipedia.org/wiki/Santa_Catarina_(state), Brasil
# *   02 Jul 2021
#
#
# **Introduction**:
#
# This project was created as a task for Module 3 (out 5) of the [Alura Bootcamp Data Sciences Applicada](https://www.alura.com.br/bootcamp/data-science-aplicada/matriculas-abertas).
#
# It is a continuation and extension of the exploratory work I already done for the first two modules of this bootcamp, when I reviewed the OpenDataSus registers of covid19 vaccination in the Brazilian State of Santa Catarina(SC) up to 30 May 20021.
#
# The main finding from this [initial work](https://github.com/amf60/which_covid19_vaccine_did_you_receive_in_SC_BR) done using a mix of terminal command line, Python&Cloab and Excel was that:
#
# > for ~ 12% of registers (out of ~ 2 Million end of May 2021), we can not confirm which vaccine an individual received when I cross-checked 3 variables from the master dataset. I named this troublesome combinations as <Font color = 'brow'>'Combinations of Concern' - CoC </Font> (step 5 here after for definition).
#
# > This ~ 12% proportion of CoC's registrations was already noticed back in March and April, when the nr of registers were less than 1 Million and so I could use only Excel.
#
# <Font color = 'green'>***DES-EXCELANDO!!!!***
#
# <font color='blue'>My objectives for this Module 3 project were:
#
#
#
# *   <font color='blue'>to use only Google Colab notebook and Python related packages, to check the OpenDataSus registration data up to 30 June 2021, and;
# *   <font color='blue'>verify if the 12 % trend of 'Combinations of Concern' is still a matter for concern end June 2021.
#
# This project is a work in progress and is being conceived and designed with the end-user in mind: the SC DIVE's UDVE managers and local vaccination teams accross the state of Santa Catarina.
#
# My final goal is that local UDVE teams may use the delivers of the final bootcamp project to help correct, clean and update their covid 19 registration files.
#
# I am also aiming a high level of automation of the entire monitoring process, so the end-users can, at any time, quickly and easily track progress of the corrective actions to address the 'Combinations of Concern' - CoC.

# %% [markdown]
# # <font color = 'blue'>**Phase 1 - importing master dataset and some data wrangling**

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
#import seaborn as sns

# %%
print('Versão do pandas -> %s' % pd.__version__)
print('Versão do numpy -> %s' % np.__version__)
print('Versão do matplotlib -> %s' % mpl.__version__)
#print('Versão do seaborn -> %s' % sns.__version__)
#print('Versão do scipy -> %s' % scipy.__version__)
# Out:
# Versão do pandas -> 1.1.5
# Versão do numpy -> 1.19.5
# Versão do matplotlib -> 3.2.2

# %% [markdown]
# # <Font color = 'green'>**Step 1** - imported the raw master csv dataset into the Google Drive folder created for this project.
#
# This is the fastest process I found to upload file into Colab (less than 2 minutes for a 1.7 GB master file).
#
# However when the file was inside the drive folder, when right clicked on it, I could not find the path to this file using pd.read_csv('').
#
# To resolve it I used tips from this [source](https://neptune.ai/blog/google-colab-dealing-with-files). That helped me transfer the file from the drive folder to Colab Files, as shown in the Alura teachings, and then to copy path to add to pd.read_csv.

# %% [markdown]
# # <Font Color = 'green'>**Step 2** - Imported the raw master file into Google Colab, renamed the headers and some data cleaning
#
# Renamed all 34 original colum's head & variable names (shorter and identifiable by column nr). For the original colunm names please check this [source](https://opendatasus.saude.gov.br/dataset/b772ee55-07cd-44d8-958f-b12edd004e0b/resource/38ead83d-b115-4219-852e-7244792bc311/download/dicionario-de-dados-vacinacao.pdf).
#
# To have the most updated dataset up to 30 Jun 2021, I downloaded the file from [OpenDataSus](https://opendatasus.saude.gov.br/dataset/covid-19-vacinacao/resource/ef3bd0b8-b605-474b-9ae5-c97390c197a8?view_id=6bf433e7-16ec-4dfa-a725-08db02322bd6) on 02 Jul 21 at 07 am, and re-named my downloaded master file to match this (sc0207_07am_csv).
#
# Per the original source records at the time of the download, the latest updated of the original database was done on 01 July 21 at 3 pm. I hope, we will have most of the updated registrations up to 30 June 2021 to compare with the data from  end May 2021 used for modules 1 and 2.
#
# FYI: between the last update done to the original source database on 29 Jun 21 and 01 Jul 21, 92.876 registrations were added to the OpenDataSus' database for the state of Santa Catarina.

# %% [markdown]
# used tip from this [link](https://www.geeksforgeeks.org/pandas-strip-whitespace-from-entire-dataframe/) to clear whitespace

# %%
sc0207_07am = pd.read_csv('/content/drive/MyDrive/Alura DS Bootcamp/Modulo 3/M3 - Projeto/0207_07am.csv', sep =';', header = 0, skipinitialspace = True, names=['c1_document_id','c2_p_id','c3_p_idade','c4_p_dn','c5_p_sex','c6_p_r_codigo','c7_p_r_valor','c8_p_ibgemunicipio','c9_p_pais','c10_p_nmmunicipio','c11_p_endereco_nmpais','c12_p_uf','c13_p_cep','c14_p_enumnacionalidade','c15_e_valor','c16_e_razaosocial','c17_e_nofantasia','c18_e_municipio_codigo','c19_e_municipio_nome', 'c20_e_uf', 'c21_v_grupoatendimento_codigo','c22_v_grupoatendimento_nome','c23_v_categoria_codigo','c24_v_categoria_nome','c25_v_lote', 'c26_v_fabricante_nome','c27_v_fabricante_referencia','c28_v_dataaplicacao','c29_v_descricao_dose','c30_v_codigo','c31_v_nome','c32_sistema_origem','c33_data_importacao_rnds','c34_id_sistema_origem'])

# %%
sc0207_07am.shape
# Out:
# (3133344, 34)

# %% [markdown]
# #<font color = 'brown'>IMPORTANT REMINDERS BEFORE WE MOVE ON:
#
#
#
# 1.   Each row, or register, correspond to the application of one dose, either Dose 1 or Dose 2. Therefore the total of 3,133,344 registrations in this dataset does not mean 3,133,344 vaccinated people in Santa Catarina.
#
# 2.   Per oficial [DIVE's boletim published on 30 June 21](http://www.dive.sc.gov.br/conteudos/boletim2021/corona48/boletim48.pdf) (but with last updated data from 26 Jun 21) the distribution betweeen doses 1 and dose 2 is:
#
# *   dose 1 -  2.259.615 (75%)
# *   dose 2 -    750.416 (25%)
# *   Total -   3.014.077 (so, not as updated as our dataset)
#
#
# 3. The four covid19 vaccines used in Santa Catarina (SC) until 30 Jun 21 are:
#
# | Vaccine <br>Manufacturers 	| Nr of <br>doses 	| Actual <br>doses interval 	| Interval changed <br>during<br> the vaccination plan <br>from 	| Vaccine available<br> in SC since? 	|
# |:-:	|:-:	|:-:	|:-:	|:-:	|
# | Coronavac_Butantan 	| 2 	| 21 to 28 days 	| 14 Days 	| 18 Jan 21 	|
# | AztraZeneca 	| 2 	| 120 days 	| 28 days 	| 23 Jan 21 	|
# | Pfizer 	| 2 	| 120 days 	| No 	| 02 May 21 	|
# | Janssen 	| 1 	| NA 	| NA 	| 24 Jun 21 	|
#
#
# The above table was easily created with a tool from this [source](https://www.tablesgenerator.com/markdown_tables) as suggested by tip from this [one](https://towardsdatascience.com/cheat-sheet-for-google-colab-63853778c093)
#
# For further information about the change of the vacination intervals [Folha de Sao Paulo - 05 May 2021](https://www1.folha.uol.com.br/equilibrioesaude/2021/05/veja-quais-sao-os-intervalos-entre-as-doses-das-vacinas-contra-covid-no-brasil-e-por-que-eles-sao-diferentes.shtml)

# %%
sc0207_07am.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3133344 entries, 0 to 3133343
# Data columns (total 34 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   c1_document_id                 object
#  1   c2_p_id                        object
#  2   c3_p_idade                     int64
#  3   c4_p_dn                        object
#  4   c5_p_sex                       object
#  5   c6_p_r_codigo                  int64
#  6   c7_p_r_valor                   object
#  7   c8_p_ibgemunicipio             float64
#  8   c9_p_pais                      float64
#  9   c10_p_nmmunicipio              object
#  10  c11_p_endereco_nmpais          object
#  11  c12_p_uf                       object
#  12  c13_p_cep                      float64
#  13  c14_p_enumnacionalidade        object
#  14  c15_e_valor                    int64
#  15  c16_e_razaosocial              object
#  16  c17_e_nofantasia               object
#  17  c18_e_municipio_codigo         int64
#  18  c19_e_municipio_nome           object
#  19  c20_e_uf                       object
#  20  c21_v_grupoatendimento_codigo  int64
#  21  c22_v_grupoatendimento_nome    object
#  22  c23_v_categoria_codigo         float64
#  23  c24_v_categoria_nome           object
#  24  c25_v_lote                     object
#  25  c26_v_fabricante_nome          object
#  26  c27_v_fabricante_referencia    object
#  27  c28_v_dataaplicacao            object
#  28  c29_v_descricao_dose           object
#  29  c30_v_codigo                   int64
#  30  c31_v_nome                     object
#  31  c32_sistema_origem             object
#  32  c33_data_importacao_rnds       object
#  33  c34_id_sistema_origem          int64
# dtypes: float64(4), int64(7), object(23)
# memory usage: 812.8+ MB

# %%
sc0207_07am.head()
# Out:
#                               c1_document_id  ... c34_id_sistema_origem
# 0  516d2087-4083-4e96-9a6b-0b7d921bc60b-i0b0  ...                 16341
# 1  38d31763-5853-41bd-974d-da2693264d67-i0b0  ...                 16341
# 2  70620076-f2c4-4f47-b7b9-02d72320d5e5-i0b0  ...                 17901
# 3  08ee6668-0ce1-45ef-99af-63e19c55c5a9-i0b0  ...                 16341
# 4  c90ace10-63c2-4c6a-8239-5665f830d8a5-i0b0  ...                 16341
#
# [5 rows x 34 columns]

# %% [markdown]
# ## <Font color = 'green'>*Converted the 3 date's columns from object to datetime.*
#
# Tips for the conversion of c33 taken from this [link](https://www.statology.org/convert-datetime-to-date-pandas/)

# %%
sc0207_07am['c4_p_dn'] = pd.to_datetime(sc0207_07am['c4_p_dn'])
sc0207_07am['c28_v_dataaplicacao'] = pd.to_datetime(sc0207_07am['c28_v_dataaplicacao'])
sc0207_07am['c33_data_importacao_rnds'] = pd.to_datetime(sc0207_07am['c33_data_importacao_rnds']).dt.date
sc0207_07am['c33_data_importacao_rnds'] = pd.to_datetime(sc0207_07am['c33_data_importacao_rnds']).dt.normalize()

# %%
sc0207_07am.tail(3)
# Out:
#                                     c1_document_id  ... c34_id_sistema_origem
# 3133341  638cb145-03ad-467b-ba61-9882daa0e69f-i0b0  ...                 17923
# 3133342  38ca7827-ef71-4a24-9685-b2a42b0be15a-i0b0  ...                 18204
# 3133343  63a51ead-7143-4968-b276-38c828053868-i0b0  ...                 18467
#
# [3 rows x 34 columns]

# %%
sc0207_07am.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3133344 entries, 0 to 3133343
# Data columns (total 34 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   c1_document_id                 object
#  1   c2_p_id                        object
#  2   c3_p_idade                     int64
#  3   c4_p_dn                        datetime64[ns]
#  4   c5_p_sex                       object
#  5   c6_p_r_codigo                  int64
#  6   c7_p_r_valor                   object
#  7   c8_p_ibgemunicipio             float64
#  8   c9_p_pais                      float64
#  9   c10_p_nmmunicipio              object
#  10  c11_p_endereco_nmpais          object
#  11  c12_p_uf                       object
#  12  c13_p_cep                      float64
#  13  c14_p_enumnacionalidade        object
#  14  c15_e_valor                    int64
#  15  c16_e_razaosocial              object
#  16  c17_e_nofantasia               object
#  17  c18_e_municipio_codigo         int64
#  18  c19_e_municipio_nome           object
#  19  c20_e_uf                       object
#  20  c21_v_grupoatendimento_codigo  int64
#  21  c22_v_grupoatendimento_nome    object
#  22  c23_v_categoria_codigo         float64
#  23  c24_v_categoria_nome           object
#  24  c25_v_lote                     object
#  25  c26_v_fabricante_nome          object
#  26  c27_v_fabricante_referencia    object
#  27  c28_v_dataaplicacao            datetime64[ns]
#  28  c29_v_descricao_dose           object
#  29  c30_v_codigo                   int64
#  30  c31_v_nome                     object
#  31  c32_sistema_origem             object
#  32  c33_data_importacao_rnds       datetime64[ns]
#  33  c34_id_sistema_origem          int64
# dtypes: datetime64[ns](3), float64(4), int64(7), object(20)
# memory usage: 812.8+ MB

# %% [markdown]
# ##<font color = 'green'>*Eliminated empty space and shortned the code for variable column 'c29_v_descricao_dose'*

# %%
sc0207_07am.loc[sc0207_07am['c29_v_descricao_dose'] == '    1ª Dose', 'c29_v_descricao_dose'] = 'D1'
sc0207_07am.loc[sc0207_07am['c29_v_descricao_dose'] == '    2ª Dose', 'c29_v_descricao_dose'] = 'D2'
sc0207_07am.head()
# Out:
#                               c1_document_id  ... c34_id_sistema_origem
# 0  516d2087-4083-4e96-9a6b-0b7d921bc60b-i0b0  ...                 16341
# 1  38d31763-5853-41bd-974d-da2693264d67-i0b0  ...                 16341
# 2  70620076-f2c4-4f47-b7b9-02d72320d5e5-i0b0  ...                 17901
# 3  08ee6668-0ce1-45ef-99af-63e19c55c5a9-i0b0  ...                 16341
# 4  c90ace10-63c2-4c6a-8239-5665f830d8a5-i0b0  ...                 16341
#
# [5 rows x 34 columns]

# %% [markdown]
# ## <Font color = 'green'>*Sorting the entire dataset based on dates of the variable 'c28_v_dataaplicacao'*

# %%
sc0207_07am.sort_values(by='c28_v_dataaplicacao', ascending=True, inplace=True)
sc0207_07am
# Out:
#                                     c1_document_id  ... c34_id_sistema_origem
# 340733   4af998fc-ba82-40e6-bfd4-d2fcde965c29-i0b0  ...                 18602
# 2878375  c0622be3-b4a1-4e4f-9c21-8e0e0cc7f7da-i0b0  ...                 18602
# 461906   d041ac6e-fdfd-4875-944e-6d2c4cc79191-i0b0  ...                 18602
# 3023718  818361b6-9747-435d-8bad-5d079290656f-i0b0  ...                 18602
# 127931   c9c8dc1f-d435-423d-94d0-5f68fe9b00e9-i0b0  ...                 18602
# ...                                            ...  ...                   ...
# 2196808  ff4af52d-c6bc-4471-9b01-3522b6515697-i0b0  ...                 16341
# 2511442  6653c3fd-00a2-43b9-b0a4-e8b69ffdb3a7-i0b0  ...                 16341
# 1115673  98d36b1f-4410-4c22-a36f-417e2b9eefd3-i0b0  ...                 16341
# 1115671  886a748a-219d-4f0a-8174-7553c7439326-i0b0  ...                 16341
# 10814    ac8003b3-702f-4a7b-b284-acf576b829d2-i0b0  ...                 16341
#
# [3133344 rows x 34 columns]

# %% [markdown]
# # <Font color ='blue'> **Phase 2 - Adding a new column in preparation for the dataset for analysis**

# %% [markdown]
# # <Font color = 'green'>**Step 3** _ Adding a column identifying the UDVE of each register (row) in the dataset.
#
# SC has 295 counties. [DIVE](http://www.dive.sc.gov.br), the local state instituition in charge of the distribution and tracking of the covid19 vaccines applications, shared the 295 in 17 UDVEs (Decentralized Epidemiological Surveillance Units in english).
#
# Usually DIVE refers to its UDVEs by the name of the main city in the region an UDVE covers.
#
# To facilitate the coding for this project I renamed the UDVEs with a number, where 01 starts on the most western side of the state of SC and double digits ones the eastern (or costal) regions.
#
# These numbers tried to match the number used for regionales by another state institution helping coordinate the covid19 vaccinations in the state, called [COSENS SC](https://www.cosemssc.org.br/regioes_de_saude/).
#
# Tried because as you may notice, DIVE is organised in 17 UDVE regions and COSEMS SC in 16 regions and their regions borders not always match. How that helps, I do not know.

# %% [markdown]
# <Font color = 'green'>Based on tip from this [source](https://stackoverflow.com/questions/63558830/how-to-create-a-new-column-in-pandas-and-add-value-to-that-new-column-based-on-t) managed to succesfully create a new column labelled 'c35_SC_UDVE_Nr', where each register got an identification for its UDVE based on the county code where the vaccine shot was applied.

# %%
def get_udve(row):
    if row ['c18_e_municipio_codigo'] in [420080,420208,420209,420215,420490,420500,420535,420640,420660,420765,420840,421100,421200,421223,421415,421507,421520,421555,421625,421670,421720,421875]:
        return 'udve01'
    elif row['c18_e_municipio_codigo'] in [420010,420253,420445,420517,420530,420560,420768,420917,420945,421055,421185,421227,421340,421610,421910,421950,421970]:
        return 'udve02'
    elif row['c18_e_municipio_codigo'] in [420050,420055,420165,420257,420310,420350,420410,420420,420435,420440,420470,420475,420543,420665,420775,420785,420895,421050,421090,421140,421145,421165,421187,421210,421290,421315,421420,421535,421568,421569,421575,421600,421690,421715,421730,421755,421775,421795,421885]:
        return 'udve03'
    elif row['c18_e_municipio_codigo'] in [420075,420127,420430,420760,420770,420780,420800,420985,421260,421310,421390,421750,421960]:
        return 'udve04'
    elif row['c18_e_municipio_codigo'] in [420005,420040,420287,420360,420390,420400,420415,420520,420670,420680,420860,420900,420920,421003,421105,421180,421790,421850,421915,421917,421985]:
        return 'udve05'
    elif row['c18_e_municipio_codigo'] in [420160,420300,420315,420480,420550,420555,420675,420757,420970,421005,421070,421300,421335,421440,421540,421550,421605,421825,421930]:
        return 'udve06'
    elif row['c18_e_municipio_codigo'] in [420213,420330,420380,420790,420810,421010,421030,421110,421220,421360,421500,421580,421830]:
        return 'udve07'
    elif row['c18_e_municipio_codigo'] in [420450,420650,420890,421060,421740]:
        return 'udve08'
    elif row['c18_e_municipio_codigo'] in [420130,420205,420210,420580,420845,420910,421620,421635]:
        return 'udve09'
    elif row['c18_e_municipio_codigo'] in [420200,420245,420320,420710,420820,420830,421000,421130,421250,421280,421350]:
        return 'udve10'
    elif row['c18_e_municipio_codigo'] in [420020,420030,420180,420190,420285,420419,420510,420690,420740,420850,420915,420950,420990,421085,421270,421370,421400,421410,421450,421460,421480,421530,421567,421780,421860,421920,421935,421940]:
        return 'udve11'
    elif row['c18_e_municipio_codigo'] in [420125,420170,420220,420240,420270,420290,420515,420590,420630,420750,421320,421470,421510,421820]:
        return 'udve12'
    elif row['c18_e_municipio_codigo'] in [420060,420070,420090,420110,420120,420230,420370,420540,420570,420600,420980,421020,421150,421190,421230,421430,421570,421590,421630,421660,421725,421800]:
        return 'udve13'
    elif row['c18_e_municipio_codigo'] in [420100,420243,420250,420260,420325,420340,420417,420455,420930,421175,421189,421205,421330,421505,421650,421680,421890,421895]:
        return 'udve14'
    elif row['c18_e_municipio_codigo'] in [420150,420280,420395,420610,420620,420720,420730,420880,420940,421240,421265,421490,421545,421560,421700,421710,421840,421870]:
        return 'udve15'
    elif row['c18_e_municipio_codigo'] in [420425,420460,420545,420700,420960,421120,421160,421170,421760,421835,421900,42200]:
        return 'udve16'
    elif row['c18_e_municipio_codigo'] in [420140,420195,420207,420519,420870,421040,421080,421125,421225,421380,421565,421640,421770,421810,421880]:
        return 'udve17'

# %%
sc0207_07am['c35_SC_UDVE_Nr'] = sc0207_07am.apply(get_udve, axis = 1)

# %%
sc0207_07am_udve = sc0207_07am

# %%
sc0207_07am_udve.head()
# Out:
#                                     c1_document_id  ... c35_SC_UDVE_Nr
# 340733   4af998fc-ba82-40e6-bfd4-d2fcde965c29-i0b0  ...         udve13
# 2878375  c0622be3-b4a1-4e4f-9c21-8e0e0cc7f7da-i0b0  ...         udve13
# 461906   d041ac6e-fdfd-4875-944e-6d2c4cc79191-i0b0  ...         udve07
# 3023718  818361b6-9747-435d-8bad-5d079290656f-i0b0  ...         udve13
# 127931   c9c8dc1f-d435-423d-94d0-5f68fe9b00e9-i0b0  ...         udve13
#
# [5 rows x 35 columns]

# %%
sc0207_07am_udve.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3133344 entries, 340733 to 10814
# Data columns (total 35 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   c1_document_id                 object
#  1   c2_p_id                        object
#  2   c3_p_idade                     int64
#  3   c4_p_dn                        datetime64[ns]
#  4   c5_p_sex                       object
#  5   c6_p_r_codigo                  int64
#  6   c7_p_r_valor                   object
#  7   c8_p_ibgemunicipio             float64
#  8   c9_p_pais                      float64
#  9   c10_p_nmmunicipio              object
#  10  c11_p_endereco_nmpais          object
#  11  c12_p_uf                       object
#  12  c13_p_cep                      float64
#  13  c14_p_enumnacionalidade        object
#  14  c15_e_valor                    int64
#  15  c16_e_razaosocial              object
#  16  c17_e_nofantasia               object
#  17  c18_e_municipio_codigo         int64
#  18  c19_e_municipio_nome           object
#  19  c20_e_uf                       object
#  20  c21_v_grupoatendimento_codigo  int64
#  21  c22_v_grupoatendimento_nome    object
#  22  c23_v_categoria_codigo         float64
#  23  c24_v_categoria_nome           object
#  24  c25_v_lote                     object
#  25  c26_v_fabricante_nome          object
#  26  c27_v_fabricante_referencia    object
#  27  c28_v_dataaplicacao            datetime64[ns]
#  28  c29_v_descricao_dose           object
#  29  c30_v_codigo                   int64
#  30  c31_v_nome                     object
#  31  c32_sistema_origem             object
#  32  c33_data_importacao_rnds       datetime64[ns]
#  33  c34_id_sistema_origem          int64
#  34  c35_SC_UDVE_Nr                 object
# dtypes: datetime64[ns](3), float64(4), int64(7), object(21)
# memory usage: 860.6+ MB

# %% [markdown]
# #<font color = 'blue'>**Phase 3 - Identifying and formally defining 'Combinations of Concern' (CoC)**

# %% [markdown]
# # <Font Color='green'>**Step 4** - Identifying and counting the different combinations between the 4 variables that allow identication of which covid19 vaccine an individual received.
#
# | Column name                               | Column name in English    | comment                       |
# |-------------|-----------------------------|---------------------------|
# |<Font color ='brown'>c26_v_fabricante_nome | c26_vaccine manufacturer  |
# |<Font color ='brown'>c30_v_codigo          | c30_v_code                |
# |<Font color ='brown'>c31_v_nome            | c31_v_name                |
# |<Font color ='brown'>c32_sistema_origem    | c32_source_system         | system used at local level to enter registration data
#
#
# The process used in this step was done based on the learning gathered from this [source](https://stackoverflow.com/questions/35268817/unique-combinations-of-values-in-selected-columns-in-pandas-data-frame-and-count)

# %%
v_fabri_codigo_nome_sysorig_sc0207_07am_udve = sc0207_07am_udve[['c26_v_fabricante_nome','c30_v_codigo','c31_v_nome', 'c32_sistema_origem',]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3133344 entries, 340733 to 10814
# Data columns (total 4 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   c26_v_fabricante_nome  object
#  1   c30_v_codigo           int64
#  2   c31_v_nome             object
#  3   c32_sistema_origem     object
# dtypes: int64(1), object(3)
# memory usage: 119.5+ MB

# %%
v_fabri_codigo_nome_sysorig_sc0207_07am_udve = sc0207_07am_udve[['c26_v_fabricante_nome','c30_v_codigo','c31_v_nome','c32_sistema_origem']]
v_fabri_codigo_nome_sysorig_sc0207_07am_udve
# Out:
#                 c26_v_fabricante_nome  ...             c32_sistema_origem
# 340733   SERUM INSTITUTE OF INDIA LTD  ...  ESUS APS - NACIONAL (OFFLINE)
# 2878375  SERUM INSTITUTE OF INDIA LTD  ...  ESUS APS - NACIONAL (OFFLINE)
# 461906   SERUM INSTITUTE OF INDIA LTD  ...  ESUS APS - NACIONAL (OFFLINE)
# 3023718  SERUM INSTITUTE OF INDIA LTD  ...  ESUS APS - NACIONAL (OFFLINE)
# 127931   SERUM INSTITUTE OF INDIA LTD  ...  ESUS APS - NACIONAL (OFFLINE)
# ...                               ...  ...                            ...
# 2196808             FUNDACAO BUTANTAN  ...                       Novo PNI
# 2511442         FUNDACAO OSWALDO CRUZ  ...                       Novo PNI
# 1115673             FUNDACAO BUTANTAN  ...                       Novo PNI
# 1115671           MINISTERIO DA SAUDE  ...                       Novo PNI
# 10814             MINISTERIO DA SAUDE  ...                       Novo PNI
#
# [3133344 rows x 4 columns]

# %%
v_fabri_codigo_nome_sysorig_sc0207_07am_udve.groupby(['c26_v_fabricante_nome','c30_v_codigo','c31_v_nome','c32_sistema_origem']).size()
# Out:
# c26_v_fabricante_nome                    c30_v_codigo  c31_v_nome                                                 c32_sistema_origem
# ASTRAZENECA AB                           85            Vacina Covid-19 - Covishield                               G-MUS                                    755
#                                                                                                                   G-MUS - Gestão Municipal de Saúde       9493
# ASTRAZENECA FARMACEUTICA DO BRASIL LTDA  85            Vacina Covid-19 - Covishield                               IPM istemas LTDA                        2348
# BUTANTAN                                 86            Covid-19-Coronavac-Sinovac/Butantan                        IPM istemas LTDA                         202
# BioNTech/Fosun Pharma/Pfizer             87            Vacina covid-19 - BNT162b2 - BioNTech/Fosun Pharma/Pfizer  ESUS APS - NACIONAL (OFFLINE)          21651
# FUNDACAO BUTANTAN                        86            Covid-19-Coronavac-Sinovac/Butantan                        G-MUS                                  68462
#                                                                                                                   G-MUS - Gestão Municipal de Saúde      39339
#                                                                                                                   IDS Saúde                                 34
#                                                                                                                   Novo PNI                             1011188
#                                                                                                                   Saudetech                              37979
#                                                                                                                   saudetech                               4840
# FUNDACAO OSWALDO CRUZ                    85            Vacina Covid-19 - Covishield                               G-MUS                                  66043
#                                                                                                                   G-MUS - Gestão Municipal de Saúde      35683
#                                                                                                                   IDS Saúde                               3664
#                                                                                                                   Novo PNI                              979119
#                                                                                                                   Saudetech                              48301
#                                                                                                                   saudetech                              15865
#                                          86            Covid-19-Coronavac-Sinovac/Butantan                        IDS Saúde                                  2
#                                                                                                                   Novo PNI                                  12
#                                          88            Vacina covid-19 - Ad26.COV2.S - Janssen-Cilag              IDS Saúde                                  1
# JANSSEN-CILAG                            88            Vacina covid-19 - Ad26.COV2.S - Janssen-Cilag              IDS SAUDE                                176
#                                                                                                                   Saudetech                               1391
# Janssen Biologics B.V.                   88            Vacina covid-19 - Ad26.COV2.S - Janssen-Cilag              G-MUS - Gestão Municipal de Saúde       1329
# Janssen-Cilag                            88            Vacina covid-19 - Ad26.COV2.S - Janssen-Cilag              ESUS APS - NACIONAL (OFFLINE)           2115
# MINISTERIO DA SAUDE                      87            Vacina covid-19 - BNT162b2 - BioNTech/Fosun Pharma/Pfizer  Novo PNI                              171280
#                                          88            Vacina covid-19 - Ad26.COV2.S - Janssen-Cilag              Novo PNI                               14984
#                                          89            Covid-19-AstraZeneca                                       Novo PNI                              117213
# OXFORD-ASTRAZENECA                       85            Vacina Covid-19 - Covishield                               IDS SAUDE                               4105
#                                                                                                                   IDS Saúde                              28444
#                                          86            Covid-19-Coronavac-Sinovac/Butantan                        IDS Saúde                                  9
#                                          87            Vacina covid-19 - BNT162b2 - BioNTech/Fosun Pharma/Pfizer  IDS Saúde                                  2
# PFIZER                                   87            Vacina covid-19 - BNT162b2 - BioNTech/Fosun Pharma/Pfizer  IPM istemas LTDA                         350
# PFIZER/BIONTECH                          86            Covid-19-Coronavac-Sinovac/Butantan                        IDS Saúde                                  1
#                                          87            Vacina covid-19 - BNT162b2 - BioNTech/Fosun Pharma/Pfizer  G-MUS                                  13941
#                                                                                                                   G-MUS - Gestão Municipal de Saúde      16860
#                                                                                                                   IDS SAUDE                                828
#                                                                                                                   IDS Saúde                               3269
#                                                                                                                   Saudetech                              15071
#                                                                                                                   saudetech                               2561
# SERUM INSTITUTE OF INDIA LTD             86            Covid-19-Coronavac-Sinovac/Butantan                        ESUS APS - NACIONAL (OFFLINE)         223321
# SERUM INSTITUTE OF INDIA LTD.            85            Vacina Covid-19 - Covishield                               G-MUS                                     65
#                                                                                                                   IDS Saúde                                  1
# SINOVAC LIFE SCIENCE CO LTD              85            Vacina Covid-19 - Covishield                               ESUS APS - NACIONAL (OFFLINE)         144865
# SINOVAC/BUTANTA                          81            Pendente Identificação                                     IDS Saúde                                436
#                                          85            Vacina Covid-19 - Covishield                               IDS Saúde                                  6
#                                          86            Covid-19-Coronavac-Sinovac/Butantan                        IDS Saúde                               7754
# SINOVAC/BUTANTAN                         86            Covid-19-Coronavac-Sinovac/Butantan                        IDS SAUDE                               3715
#                                                                                                                   IDS Saúde                              14271
# dtype: int64

# %% [markdown]
# # <Font color = 'green'>**Step 5** - Defining and creating a new column ['c_36_Combination_of_Concern'] that identify and classify 'combinations of concern' based on their frequency.
#
# #<Font color = 'brown'>**Definition of Combination of Concern(CoC)'**: within an individual vaccination registration, any combination between the 4 variables above mentioned that would raise doubt about which covid vaccine an individual received.
#
# Per example: 'SERUM INSTITUTE OF INDIA LTD' is ONE OF the manufacturers across the globe for AztraZeneca(AZ) covid 19 related vaccines. AZ covid19 vaccines produced by SERUM are known as ['COVISHIELD'](https://www.bbc.com/news/health-57695835).  That's inconsistent with a 'c31_v_nome' = 'Covid-19-Coronavac-Sinovac/Butantan' in the same register, as this last one is manufactured by Coronavac China and/or Butantan Brasil.
#
# For more details about identification of covid19 vaccine manufacturers and vaccine names please check references at these [ANVISA source]((https://www.gov.br/anvisa/pt-br/assuntos/paf/coronavirus/vacinas)) re-accessed on 26 Jun 2021.
#
# # <font color ='brown'> Coding 'Combinations of Concern' based on their frequency.
#
# *   <Font color = 'brown'>**CoC_1** = Very High Frequency - more than 100,000 registers
# *   <Font color = 'brown'>**CoC_2** = High Frequency - between 10,000 and 100,000 registers
# *   <Font color = 'brown'>**CoC_3** = 'Low' Frequency - less than 10,000 registers
# *   <Font color = 'brown'>**'no_issue'** = At best knowledge of this author no remarkble issue identified at the time this project was prepared ( 30 June 2021)
#
# <font color = 'brown'>**Author's note:** Strictly speaking, from the Pharmacovigilance point of view, 'no issue' is not strictly correct. But it will fulfill for the moment the purpose of this part of the work. More details in the conclusion at the end.
#
# The set of codes here after I was inspired by tips from this [source](https://towardsdatascience.com/the-ultimate-guide-for-column-creation-with-pandas-dataframes-83b8c565110e)

# %%
def combination_of_concern(row):
    if row['c26_v_fabricante_nome'] == 'SERUM INSTITUTE OF INDIA LTD' and row['c30_v_codigo'] == 86 and row['c31_v_nome'] == 'Covid-19-Coronavac-Sinovac/Butantan':
        return 'CoC_1'
    elif row['c26_v_fabricante_nome'] == 'SINOVAC LIFE SCIENCE CO LTD' and row['c30_v_codigo'] == 85 and row['c31_v_nome'] == 'Vacina Covid-19 - Covishield':
        return 'CoC_1'
    elif row['c26_v_fabricante_nome'] == 'MINISTERIO DA SAUDE' and row['c30_v_codigo'] == 89 and row['c31_v_nome'] == 'Covid-19-AstraZeneca ':
        return 'CoC_1'
    elif row['c26_v_fabricante_nome'] == 'SINOVAC/BUTANTA' and row['c30_v_codigo'] == 85 and row['c31_v_nome'] == 'Vacina Covid-19 - Covishield':
        return 'CoC_3'
    elif row['c26_v_fabricante_nome'] == 'SINOVAC/BUTANTA' and row['c30_v_codigo'] == 81 and row['c31_v_nome'] == 'Pendente Identificação':
        return 'CoC_3'
    elif row['c26_v_fabricante_nome'] == 'FUNDACAO OSWALDO CRUZ' and row['c30_v_codigo'] == 86 and row['c31_v_nome'] == 'Covid-19-Coronavac-Sinovac/Butantan':
        return 'CoC_3'
    elif row['c26_v_fabricante_nome'] == 'FUNDACAO OSWALDO CRUZ' and row['c30_v_codigo'] == 88 and row['c31_v_nome'] == 'Vacina covid-19 - Ad26.COV2.S - Janssen-Cilag':
        return 'CoC_3'
    elif row['c26_v_fabricante_nome'] == 'OXFORD-ASTRAZENECA' and row['c30_v_codigo'] == 86 and row['c31_v_nome'] == 'Covid-19-Coronavac-Sinovac/Butantan':
        return 'CoC_3'
    elif row['c26_v_fabricante_nome'] == 'OXFORD-ASTRAZENECA' and row['c30_v_codigo'] == 87 and row['c31_v_nome'] == 'Vacina covid-19 - BNT162b2 - BioNTech/Fosun Ph...':
        return 'CoC_3'
    elif row['c26_v_fabricante_nome'] == 'BioNTech/Fosun Pharma/Pfizer' and row['c30_v_codigo'] == 87 and row['c31_v_nome'] == 'Vacina covid-19 - BNT162b2 - BioNTech/Fosun Ph...':
        return 'CoC_3'
    elif row['c26_v_fabricante_nome'] == 'PFIZER/BIONTECH' and row['c30_v_codigo'] == 86 and row['c31_v_nome'] == 'Covid-19-Coronavac-Sinovac/Butantan':
        return 'CoC_3'
    elif row['c26_v_fabricante_nome'] == 'INTERVAX LTDA' and row['c30_v_codigo'] == 85 and row['c31_v_nome'] == 'Vacina Covid-19 - Covishield':
        return 'CoC_3'
    else:
        return 'no_issue'

# %% [markdown]
# #<font color = 'brown'> When compared to last previous update on 30 May 2021, we notice the following changes in the 'Combination of Concern' categories:
#
# *   <font color = 'blue'> A significant increase on the nr of CoC_1 groups (1 to 3). The previously two CoC_2 groups from 30 May 21 significantly increased in frequency and therefore shifted to CoC_1 (''SINOVAC LIFE SCIENCE CO LTD' ...) and ('MINISTERIO DA SAUDE' ... )
# *   <font color = 'blue'> No new CoC_2 group in June (there was 2 in May);
# *   <font color = 'blue'> No new group added to the CoC_3 category in June. Same profile of the C0C_3 groups recorded last May.
#
# The data above mays suggest that clean up of the database is not happening in systematic and large scale.

# %%
sc0207_07am_udve['c_36_Combination_of_Concern'] = sc0207_07am_udve.apply(combination_of_concern, axis=1)

# %%
sc0207_07am_udve_CoC = sc0207_07am_udve

# %%
sc0207_07am_udve_CoC.c_36_Combination_of_Concern.unique()
# Out:
# array(['CoC_1', 'no_issue', 'CoC_3'], dtype=object)

# %%
sc0207_07am_udve_CoC.tail()
# Out:
#                                     c1_document_id  ... c_36_Combination_of_Concern
# 2196808  ff4af52d-c6bc-4471-9b01-3522b6515697-i0b0  ...                    no_issue
# 2511442  6653c3fd-00a2-43b9-b0a4-e8b69ffdb3a7-i0b0  ...                    no_issue
# 1115673  98d36b1f-4410-4c22-a36f-417e2b9eefd3-i0b0  ...                    no_issue
# 1115671  886a748a-219d-4f0a-8174-7553c7439326-i0b0  ...                    no_issue
# 10814    ac8003b3-702f-4a7b-b284-acf576b829d2-i0b0  ...                    no_issue
#
# [5 rows x 36 columns]

# %% [markdown]
# # <Font color ='blue'>**Phase 4 - Crosstabing UDVE and CoC at county level**

# %% [markdown]
# # <Font color = 'green'>**Step 6** - Crosstabing UDVE and CoC
#
# Tips from Alura curso 'Estatistica com Python parte 1: Frequencias e Medidas - aula 2 - Distribuicao de frequencia + for formating right - [source](https://stackoverflow.com/questions/17232013/how-to-set-the-pandas-dataframe-data-left-right-alignment) and [source](https://pbpython.com/styling-pandas.html)

# %%
udve_CoC = pd.crosstab(sc0207_07am_udve_CoC.c35_SC_UDVE_Nr , sc0207_07am_udve_CoC.c_36_Combination_of_Concern)
def highlight(s):
    if s.CoC_1 > 100000:
        return ['background-color: red'] * 3
    elif (s.CoC_1 > 10000) and (s.CoC_1 < 100000):
        return ['background-color: orange'] * 3
    elif (s.CoC_1 > 1000) and (s.CoC_1 < 10000):
        return ['background-color: yellow'] * 3
    else:
        return ['background-color: white'] * 3

udve_CoC.style.set_properties(**{'text-align': 'right'}).format('{0:,.0f}').apply(highlight, axis=1)
# Out:
# <style  type="text/css" >
# #T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row0_col0,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row0_col1,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row0_col2,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row1_col0,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row1_col1,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row1_col2,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row4_col0,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row4_col1,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row4_col2,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row11_col0,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row11_col1,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row11_col2,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row13_col0,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row13_col1,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row13_col2,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row14_col0,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row14_col1,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row14_col2,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row15_col0,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row15_col1,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row15_col2{
#             text-align:  right;
#             background-color:  yellow;
#         }#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row2_col0,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row2_col1,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row2_col2,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row5_col0,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row5_col1,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row5_col2,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row6_col0,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row6_col1,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row6_col2,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row8_col0,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row8_col1,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row8_col2,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row9_col0,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row9_col1,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row9_col2{
#             text-align:  right;
#             background-color:  orange;
#         }#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row3_col0,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row3_col1,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row3_col2,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row7_col0,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row7_col1,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row7_col2,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row10_col0,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row10_col1,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row10_col2,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row16_col0,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row16_col1,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row16_col2{
#             text-align:  right;
#             background-color:  white;
#         }#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row12_col0,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row12_col1,#T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row12_col2{
#             text-align:  right;
#             background-color:  red;
#         }</style><table id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002" ><thead>    <tr>        <th class="index_name level0" >c_36_Combination_of_Concern</th>        <th class="col_heading level0 col0" >CoC_1</th>        <th class="col_heading level0 col1" >CoC_3</th>        <th class="col_heading level0 col2" >no_issue</th>    </tr>    <tr>        <th class="index_name level0" >c35_SC_UDVE_Nr</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002level0_row0" class="row_heading level0 row0" >udve01</th>
#                         <td id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row0_col0" class="data row0 col0" >3,001</td>
#                         <td id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row0_col2" class="data row0 col2" >104,380</td>
#             </tr>
#             <tr>
#                         <th id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002level0_row1" class="row_heading level0 row1" >udve02</th>
#                         <td id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row1_col0" class="data row1 col0" >8,944</td>
#                         <td id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row1_col1" class="data row1 col1" >0</td>
#                         <td id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row1_col2" class="data row1 col2" >64,017</td>
#             </tr>
#             <tr>
#                         <th id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002level0_row2" class="row_heading level0 row2" >udve03</th>
#                         <td id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row2_col0" class="data row2 col0" >16,789</td>
#                         <td id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row2_col1" class="data row2 col1" >0</td>
#                         <td id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row2_col2" class="data row2 col2" >235,006</td>
#             </tr>
#             <tr>
#                         <th id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002level0_row3" class="row_heading level0 row3" >udve04</th>
#                         <td id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row3_col0" class="data row3 col0" >52</td>
#                         <td id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row3_col1" class="data row3 col1" >0</td>
#                         <td id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row3_col2" class="data row3 col2" >76,558</td>
#             </tr>
#             <tr>
#                         <th id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002level0_row4" class="row_heading level0 row4" >udve05</th>
#                         <td id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row4_col0" class="data row4 col0" >1,579</td>
#                         <td id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row4_col1" class="data row4 col1" >0</td>
#                         <td id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row4_col2" class="data row4 col2" >102,668</td>
#             </tr>
#             <tr>
#                         <th id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002level0_row5" class="row_heading level0 row5" >udve06</th>
#                         <td id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row5_col0" class="data row5 col0" >21,537</td>
#                         <td id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row5_col1" class="data row5 col1" >0</td>
#                         <td id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row5_col2" class="data row5 col2" >102,344</td>
#             </tr>
#             <tr>
#                         <th id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002level0_row6" class="row_heading level0 row6" >udve07</th>
#                         <td id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row6_col0" class="data row6 col0" >31,151</td>
#                         <td id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row6_col1" class="data row6 col1" >27</td>
#                         <td id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row6_col2" class="data row6 col2" >114,479</td>
#             </tr>
#             <tr>
#                         <th id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002level0_row7" class="row_heading level0 row7" >udve08</th>
#                         <td id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row7_col0" class="data row7 col0" >0</td>
#                         <td id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row7_col1" class="data row7 col1" >0</td>
#                         <td id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row7_col2" class="data row7 col2" >104,834</td>
#             </tr>
#             <tr>
#                         <th id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002level0_row8" class="row_heading level0 row8" >udve09</th>
#                         <td id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row8_col0" class="data row8 col0" >21,845</td>
#                         <td id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row8_col1" class="data row8 col1" >1</td>
#                         <td id="T_b95f421c_dd09_11eb_aaf2_0242ac1c0002row8_col2" class="data row8 col2" >304,253</td>
#             </tr>
#             <tr>
#                         <t

# %% [markdown]
# Tip from [source](https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html) (Finer Control: Display Values)

# %% [markdown]
# # <font color = 'green'>Proportions of CoCs categories per UDVE
#
# tip [source](https://stackoverflow.com/questions/50820659/compute-row-percentages-in-pandas-dataframe)
#
# UDVEs 13, 7, 6, 9, 10 and 3 are, respectively, the ones of greatest concern due to the potential large cluster of unknown vaccination status (CoC1), based on the data of this dataset.
#
# <Font color = 'red'>Percentual - a great example of how 'data cleaning' in clinical data sciences can be a very sensitive matter. CoC_3 is low in frequency but potentially high in consequencies ('No one is safe, until everyone is'). Low percentage does not mean 'low risk'.

# %%
Per_udve_CoC = udve_CoC[['CoC_1','CoC_3','no_issue']] = udve_CoC[['CoC_1','CoC_3','no_issue']].apply(lambda x: x/x.sum(), axis=1) * 1

Per_udve_CoC.style.set_properties(**{'text-align': 'right'}).format("{:.2%}")
# Out:
# <style  type="text/css" >
# #T_b966606a_dd09_11eb_aaf2_0242ac1c0002row0_col0,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row0_col1,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row0_col2,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row1_col0,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row1_col1,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row1_col2,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row2_col0,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row2_col1,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row2_col2,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row3_col0,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row3_col1,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row3_col2,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row4_col0,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row4_col1,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row4_col2,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row5_col0,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row5_col1,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row5_col2,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row6_col0,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row6_col1,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row6_col2,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row7_col0,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row7_col1,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row7_col2,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row8_col0,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row8_col1,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row8_col2,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row9_col0,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row9_col1,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row9_col2,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row10_col0,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row10_col1,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row10_col2,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row11_col0,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row11_col1,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row11_col2,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row12_col0,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row12_col1,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row12_col2,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row13_col0,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row13_col1,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row13_col2,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row14_col0,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row14_col1,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row14_col2,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row15_col0,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row15_col1,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row15_col2,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row16_col0,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row16_col1,#T_b966606a_dd09_11eb_aaf2_0242ac1c0002row16_col2{
#             text-align:  right;
#         }</style><table id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002" ><thead>    <tr>        <th class="index_name level0" >c_36_Combination_of_Concern</th>        <th class="col_heading level0 col0" >CoC_1</th>        <th class="col_heading level0 col1" >CoC_3</th>        <th class="col_heading level0 col2" >no_issue</th>    </tr>    <tr>        <th class="index_name level0" >c35_SC_UDVE_Nr</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002level0_row0" class="row_heading level0 row0" >udve01</th>
#                         <td id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002row0_col0" class="data row0 col0" >2.79%</td>
#                         <td id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002row0_col1" class="data row0 col1" >0.00%</td>
#                         <td id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002row0_col2" class="data row0 col2" >97.21%</td>
#             </tr>
#             <tr>
#                         <th id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002level0_row1" class="row_heading level0 row1" >udve02</th>
#                         <td id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002row1_col0" class="data row1 col0" >12.26%</td>
#                         <td id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002row1_col1" class="data row1 col1" >0.00%</td>
#                         <td id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002row1_col2" class="data row1 col2" >87.74%</td>
#             </tr>
#             <tr>
#                         <th id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002level0_row2" class="row_heading level0 row2" >udve03</th>
#                         <td id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002row2_col0" class="data row2 col0" >6.67%</td>
#                         <td id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002row2_col1" class="data row2 col1" >0.00%</td>
#                         <td id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002row2_col2" class="data row2 col2" >93.33%</td>
#             </tr>
#             <tr>
#                         <th id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002level0_row3" class="row_heading level0 row3" >udve04</th>
#                         <td id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002row3_col0" class="data row3 col0" >0.07%</td>
#                         <td id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002row3_col1" class="data row3 col1" >0.00%</td>
#                         <td id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002row3_col2" class="data row3 col2" >99.93%</td>
#             </tr>
#             <tr>
#                         <th id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002level0_row4" class="row_heading level0 row4" >udve05</th>
#                         <td id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002row4_col0" class="data row4 col0" >1.51%</td>
#                         <td id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002row4_col1" class="data row4 col1" >0.00%</td>
#                         <td id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002row4_col2" class="data row4 col2" >98.49%</td>
#             </tr>
#             <tr>
#                         <th id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002level0_row5" class="row_heading level0 row5" >udve06</th>
#                         <td id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002row5_col0" class="data row5 col0" >17.39%</td>
#                         <td id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002row5_col1" class="data row5 col1" >0.00%</td>
#                         <td id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002row5_col2" class="data row5 col2" >82.61%</td>
#             </tr>
#             <tr>
#                         <th id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002level0_row6" class="row_heading level0 row6" >udve07</th>
#                         <td id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002row6_col0" class="data row6 col0" >21.39%</td>
#                         <td id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002row6_col1" class="data row6 col1" >0.02%</td>
#                         <td id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002row6_col2" class="data row6 col2" >78.59%</td>
#             </tr>
#             <tr>
#                         <th id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002level0_row7" class="row_heading level0 row7" >udve08</th>
#                         <td id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002row7_col0" class="data row7 col0" >0.00%</td>
#                         <td id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002row7_col1" class="data row7 col1" >0.00%</td>
#                         <td id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002row7_col2" class="data row7 col2" >100.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002level0_row8" class="row_heading level0 row8" >udve09</th>
#                         <td id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002row8_col0" class="data row8 col0" >6.70%</td>
#                         <td id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002row8_col1" class="data row8 col1" >0.00%</td>
#                         <td id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002row8_col2" class="data row8 col2" >93.30%</td>
#             </tr>
#             <tr>
#                         <th id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002level0_row9" class="row_heading level0 row9" >udve10</th>
#                         <td id="T_b966606a_dd09_11eb_aaf2_0242ac1c0002row9_col0" class="data row9 col0" >6.76%</td>
#                         <

# %% [markdown]
# # <Font color = 'green'>**Step 07** - Crosstabing UDVE and CoC, per county, for the two UDVES with the highest frequency of 'Combinations of Concern'(CoC): UDVEs 13 and 07 respectively.

# %% [markdown]
# # <font color ='red'>**UDVE 13**

# %%
udve_13 = sc0207_07am_udve_CoC.loc[sc0207_07am_udve_CoC['c35_SC_UDVE_Nr'] == 'udve13']
udve_13.shape
# Out:
# (447464, 36)

# %%
udve_13_CoC = pd.crosstab(udve_13.c19_e_municipio_nome , udve_13.c_36_Combination_of_Concern)
udve_13_CoC.style.set_properties(**{'text-align': 'right'}).format('{0:,.0f}')
# Out:
# <style  type="text/css" >
# #T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row0_col0,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row0_col1,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row1_col0,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row1_col1,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row2_col0,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row2_col1,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row3_col0,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row3_col1,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row4_col0,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row4_col1,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row5_col0,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row5_col1,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row6_col0,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row6_col1,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row7_col0,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row7_col1,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row8_col0,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row8_col1,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row9_col0,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row9_col1,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row10_col0,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row10_col1,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row11_col0,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row11_col1,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row12_col0,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row12_col1,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row13_col0,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row13_col1,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row14_col0,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row14_col1,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row15_col0,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row15_col1,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row16_col0,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row16_col1,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row17_col0,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row17_col1,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row18_col0,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row18_col1,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row19_col0,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row19_col1,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row20_col0,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row20_col1,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row21_col0,#T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row21_col1{
#             text-align:  right;
#         }</style><table id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002" ><thead>    <tr>        <th class="index_name level0" >c_36_Combination_of_Concern</th>        <th class="col_heading level0 col0" >CoC_1</th>        <th class="col_heading level0 col1" >no_issue</th>    </tr>    <tr>        <th class="index_name level0" >c19_e_municipio_nome</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002level0_row0" class="row_heading level0 row0" >AGUAS MORNAS</th>
#                         <td id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row0_col0" class="data row0 col0" >45</td>
#                         <td id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row0_col1" class="data row0 col1" >3,773</td>
#             </tr>
#             <tr>
#                         <th id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002level0_row1" class="row_heading level0 row1" >ALFREDO WAGNER</th>
#                         <td id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row1_col0" class="data row1 col0" >0</td>
#                         <td id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row1_col1" class="data row1 col1" >4,811</td>
#             </tr>
#             <tr>
#                         <th id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002level0_row2" class="row_heading level0 row2" >ANGELINA</th>
#                         <td id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row2_col0" class="data row2 col0" >0</td>
#                         <td id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row2_col1" class="data row2 col1" >2,472</td>
#             </tr>
#             <tr>
#                         <th id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002level0_row3" class="row_heading level0 row3" >ANITAPOLIS</th>
#                         <td id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row3_col0" class="data row3 col0" >770</td>
#                         <td id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row3_col1" class="data row3 col1" >1,207</td>
#             </tr>
#             <tr>
#                         <th id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002level0_row4" class="row_heading level0 row4" >ANTONIO CARLOS</th>
#                         <td id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row4_col0" class="data row4 col0" >816</td>
#                         <td id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row4_col1" class="data row4 col1" >4,408</td>
#             </tr>
#             <tr>
#                         <th id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002level0_row5" class="row_heading level0 row5" >BIGUACU</th>
#                         <td id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row5_col0" class="data row5 col0" >0</td>
#                         <td id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row5_col1" class="data row5 col1" >32,875</td>
#             </tr>
#             <tr>
#                         <th id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002level0_row6" class="row_heading level0 row6" >CANELINHA</th>
#                         <td id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row6_col0" class="data row6 col0" >0</td>
#                         <td id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row6_col1" class="data row6 col1" >4,620</td>
#             </tr>
#             <tr>
#                         <th id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002level0_row7" class="row_heading level0 row7" >FLORIANOPOLIS</th>
#                         <td id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row7_col0" class="data row7 col0" >146,171</td>
#                         <td id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row7_col1" class="data row7 col1" >6,825</td>
#             </tr>
#             <tr>
#                         <th id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002level0_row8" class="row_heading level0 row8" >GAROPABA</th>
#                         <td id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row8_col0" class="data row8 col0" >0</td>
#                         <td id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row8_col1" class="data row8 col1" >12,354</td>
#             </tr>
#             <tr>
#                         <th id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002level0_row9" class="row_heading level0 row9" >GOVERNADOR CELSO RAMOS</th>
#                         <td id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row9_col0" class="data row9 col0" >42</td>
#                         <td id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row9_col1" class="data row9 col1" >7,091</td>
#             </tr>
#             <tr>
#                         <th id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002level0_row10" class="row_heading level0 row10" >LEOBERTO LEAL</th>
#                         <td id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row10_col0" class="data row10 col0" >0</td>
#                         <td id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row10_col1" class="data row10 col1" >1,778</td>
#             </tr>
#             <tr>
#                         <th id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002level0_row11" class="row_heading level0 row11" >MAJOR GERCINO</th>
#                         <td id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row11_col0" class="data row11 col0" >1</td>
#                         <td id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row11_col1" class="data row11 col1" >1,993</td>
#             </tr>
#             <tr>
#                         <th id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002level0_row12" class="row_heading level0 row12" >NOVA TRENTO</th>
#                         <td id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row12_col0" class="data row12 col0" >2,738</td>
#                         <td id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002row12_col1" class="data row12 col1" >6,252</td>
#             </tr>
#             <tr>
#                         <th id="T_baba75dc_dd09_11eb_aaf2_0242ac1c0002level0_row13" class="row_heading leve

# %% [markdown]
# #<Font color = 'orange'>**UDVE 07**

# %%
udve_07 = sc0207_07am_udve_CoC.loc[sc0207_07am_udve_CoC['c35_SC_UDVE_Nr'] == 'udve07']
udve_07.shape
# Out:
# (145657, 36)

# %%
udve_07_CoC = pd.crosstab(udve_07.c19_e_municipio_nome , udve_07.c_36_Combination_of_Concern)
udve_07_CoC.style.set_properties(**{'text-align': 'right'}).format('{0:,.0f}')
# Out:
# <style  type="text/css" >
# #T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row0_col0,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row0_col1,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row0_col2,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row1_col0,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row1_col1,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row1_col2,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row2_col0,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row2_col1,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row2_col2,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row3_col0,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row3_col1,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row3_col2,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row4_col0,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row4_col1,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row4_col2,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row5_col0,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row5_col1,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row5_col2,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row6_col0,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row6_col1,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row6_col2,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row7_col0,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row7_col1,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row7_col2,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row8_col0,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row8_col1,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row8_col2,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row9_col0,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row9_col1,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row9_col2,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row10_col0,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row10_col1,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row10_col2,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row11_col0,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row11_col1,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row11_col2,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row12_col0,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row12_col1,#T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row12_col2{
#             text-align:  right;
#         }</style><table id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002" ><thead>    <tr>        <th class="index_name level0" >c_36_Combination_of_Concern</th>        <th class="col_heading level0 col0" >CoC_1</th>        <th class="col_heading level0 col1" >CoC_3</th>        <th class="col_heading level0 col2" >no_issue</th>    </tr>    <tr>        <th class="index_name level0" >c19_e_municipio_nome</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002level0_row0" class="row_heading level0 row0" >BELA VISTA DO TOLDO</th>
#                         <td id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row0_col2" class="data row0 col2" >2,488</td>
#             </tr>
#             <tr>
#                         <th id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002level0_row1" class="row_heading level0 row1" >CAMPO ALEGRE</th>
#                         <td id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row1_col0" class="data row1 col0" >0</td>
#                         <td id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row1_col1" class="data row1 col1" >0</td>
#                         <td id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row1_col2" class="data row1 col2" >5,314</td>
#             </tr>
#             <tr>
#                         <th id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002level0_row2" class="row_heading level0 row2" >CANOINHAS</th>
#                         <td id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row2_col0" class="data row2 col0" >0</td>
#                         <td id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row2_col1" class="data row2 col1" >19</td>
#                         <td id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row2_col2" class="data row2 col2" >18,791</td>
#             </tr>
#             <tr>
#                         <th id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002level0_row3" class="row_heading level0 row3" >IRINEOPOLIS</th>
#                         <td id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row3_col0" class="data row3 col0" >0</td>
#                         <td id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row3_col1" class="data row3 col1" >0</td>
#                         <td id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row3_col2" class="data row3 col2" >4,472</td>
#             </tr>
#             <tr>
#                         <th id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002level0_row4" class="row_heading level0 row4" >ITAIOPOLIS</th>
#                         <td id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row4_col0" class="data row4 col0" >172</td>
#                         <td id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row4_col1" class="data row4 col1" >8</td>
#                         <td id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row4_col2" class="data row4 col2" >8,683</td>
#             </tr>
#             <tr>
#                         <th id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002level0_row5" class="row_heading level0 row5" >MAFRA</th>
#                         <td id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row5_col0" class="data row5 col0" >26,573</td>
#                         <td id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row5_col1" class="data row5 col1" >0</td>
#                         <td id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row5_col2" class="data row5 col2" >2,551</td>
#             </tr>
#             <tr>
#                         <th id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002level0_row6" class="row_heading level0 row6" >MAJOR VIEIRA</th>
#                         <td id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row6_col0" class="data row6 col0" >0</td>
#                         <td id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row6_col1" class="data row6 col1" >0</td>
#                         <td id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row6_col2" class="data row6 col2" >3,356</td>
#             </tr>
#             <tr>
#                         <th id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002level0_row7" class="row_heading level0 row7" >MONTE CASTELO</th>
#                         <td id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row7_col0" class="data row7 col0" >397</td>
#                         <td id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row7_col1" class="data row7 col1" >0</td>
#                         <td id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row7_col2" class="data row7 col2" >3,551</td>
#             </tr>
#             <tr>
#                         <th id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002level0_row8" class="row_heading level0 row8" >PAPANDUVA</th>
#                         <td id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row8_col0" class="data row8 col0" >0</td>
#                         <td id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row8_col1" class="data row8 col1" >0</td>
#                         <td id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row8_col2" class="data row8 col2" >8,277</td>
#             </tr>
#             <tr>
#                         <th id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002level0_row9" class="row_heading level0 row9" >PORTO UNIAO</th>
#                         <td id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row9_col0" class="data row9 col0" >0</td>
#                         <td id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row9_col1" class="data row9 col1" >0</td>
#                         <td id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row9_col2" class="data row9 col2" >17,884</td>
#             </tr>
#             <tr>
#                         <th id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002level0_row10" class="row_heading level0 row10" >RIO NEGRINHO</th>
#                         <td id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row10_col0" class="data row10 col0" >3,936</td>
#                         <td id="T_bafbb92a_dd09_11eb_aaf2_0242ac1c0002row10_col1" class="data row10 col1" >0</td>

# %% [markdown]
# # <Font Color = 'blue'> **PHASE 5** - 'Time Serie' Exploration

# %% [markdown]
# #<Font color='green'> **Step 08** - Counting total nr of registers per month

# %% [markdown]
# Tips from [source](https://stackoverflow.com/questions/38792122/how-to-group-and-count-rows-by-month-and-year-using-pandas)

# %%
c_28 = sc0207_07am_udve_CoC['c28_v_dataaplicacao'].groupby([sc0207_07am_udve_CoC['c28_v_dataaplicacao'].dt.year.rename('year'), sc0207_07am_udve_CoC['c28_v_dataaplicacao'].dt.month.rename('month')]).agg({'count'})
c_28
# Out:
#              count
# year month
# 2020 12          3
# 2021 1       68348
#      2      171546
#      3      597378
#      4      784707
#      5      687679
#      6      823683

# %% [markdown]
# # <Font Color = 'green'>**Step 9** - Checking 'Combination of Concern' frequency since start of covid19 vaccination in Santa Catarina as per dataset sc0207_07am.
#
# Tips from [source](https://stackoverflow.com/questions/44908383/how-can-i-group-by-month-from-a-date-field-using-python-pandas)

# %%
c28_36 = sc0207_07am_udve_CoC.groupby([(sc0207_07am_udve_CoC['c28_v_dataaplicacao'].dt.strftime('%B')),'c_36_Combination_of_Concern']).size()
c28_36
# Out:
# c28_v_dataaplicacao  c_36_Combination_of_Concern
# April                CoC_1                          103964
#                      CoC_3                               6
#                      no_issue                       680737
# December             CoC_1                               3
# February             CoC_1                           34385
#                      CoC_3                              13
#                      no_issue                       137148
# January              CoC_1                           11834
#                      CoC_3                               9
#                      no_issue                        56505
# June                 CoC_1                           47241
#                      no_issue                       776442
# March                CoC_1                          112652
#                      CoC_3                             437
#                      no_issue                       484289
# May                  CoC_1                           58107
#                      CoC_3                               2
#                      no_issue                       629570
# dtype: int64

# %% [markdown]
# <Font color = 'red'> Here I could try to find out how to pivot the table above to the wished result here after (done manually). However, I enjoy this 'sensorial tête_à_tête' with the data as it provides very interesting insights.
#
# Per example we notice that:
#
#
# *   Wrong registrations entered for December 2020 are still not corrected (vaccination in SC only started on 18 Jan 21);
# *   When we compare data from end Mai wiht end June we notice that frequency for category CoC_1 is still raising for the early months of January, February and March, but reducing for April, May and June.

# %%
sc0207_07am_c_28_c_36 = {'Month':    ['December','January','February', 'March', 'April',  'May',  'June'],
            'CoC_1':     [3,             11834,    34385,   112652,  103964,  58107,   47241],
            'CoC_2':     [0,                 0,        0,        0,       0,      0,       0],
            'CoC_3':     [0,                 9,       13,      437,       6,      2,       0],
            'no_issue':  [0,             56505,   137148,   484289,  680737, 629570,  776442]}

# %%
sc0207_07am_df_c_28_c_36 = pd.DataFrame(data=sc0207_07am_c_28_c_36)
sc0207_07am_df_c_28_c_36
# Out:
#       Month   CoC_1  CoC_2  CoC_3  no_issue
# 0  December       3      0      0         0
# 1   January   11834      0      9     56505
# 2  February   34385      0     13    137148
# 3     March  112652      0    437    484289
# 4     April  103964      0      6    680737
# 5       May   58107      0      2    629570
# 6      June   47241      0      0    776442

# %% [markdown]
# #<font color = 'green'>**Step 10** - Recalling data from 30 May 2021 for comparisons with data from up to 30 June 2021:

# %%
sc3005_c_28_c_36 = {'Month':['December', 'January',  'February', 'March', 'April',  'May'],
                    'CoC_1':   [3,            9191,       25045,   92355,   63923,   5293],
                    'CoC_2':   [0,            2539,        6312,   16436,   36890,  58452],
                    'CoC_3':   [0,               9,          12,       3,       8,      3],
                 'no_issue':   [0,           56134,      136639,   476531, 650123, 427518]}

# %%
sc3005_df_c_28_c_36 = pd.DataFrame(data=sc3005_c_28_c_36)
sc3005_df_c_28_c_36
# Out:
#       Month  CoC_1  CoC_2  CoC_3  no_issue
# 0  December      3      0      0         0
# 1   January   9191   2539      9     56134
# 2  February  25045   6312     12    136639
# 3     March  92355  16436      3    476531
# 4     April  63923  36890      8    650123
# 5       May   5293  58452      3    427518

# %% [markdown]
# # **<Font color='blue'>Brief Comments and conclusions:**
#
# *   <font color = 'green'>**DES_EXCELEI !!!** </font>- With the help of the Alura Bootcamp DS 2, Aluras courses Programming with Python, Python for DataSciences, services as stackoverflow, medium and others, I accomplished my objective to deliver this module 3 project entirely within one Google Colab notebook using Python related packages.
#
# *   We notice that, in Santa Catarina, on 30 Jun 21, the overall trend of 12% registrations of covid_19 vaccinations with 'Combinations of Concern' is still valid (368,833 (CoC_1 + CoC_3) out of a total of 3,133,344 registrations).
#
# *   UDVE 13 alone clusters 62% of the state total of 'Combinations of Concern' (229,208 out of 368,833).
#
# *   "'*No_issue*'" - as already mentioned, from the pharmacovigilance point of view, is not totally correct, as I noticed some other 'combinations of worrying' (to distinguish of the definition of 'CoC'). So I may tackle 'combinations of worrying' in the projects of the next two modules of this bootcamp.
#
# *   Finally, as explained, I am tailoring all the above with the end_user in mind: the SC UDVE manager and local teams at the each 'vaccination center'. Therefore, at the end of this bootcamp we may use the material above to easily identify and isolate all the registrations with 'combinations of concern' for appreciation at several levels - UDVE, county, vaccination center, etc. More about how that can be done in a sensitive way with efficiente Risk Based Monitoring techniques I use in clinical trials may be presented in the next two modules.
